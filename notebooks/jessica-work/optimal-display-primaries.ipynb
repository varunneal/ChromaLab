# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from colour import wavelength_to_XYZ

# %%
from chromalab.observer import Observer, Cone, getsRGBfromWavelength
from chromalab.spectra import Spectra, Illuminant
from chromalab.maxbasis import MaxBasis
from chromalab.maxdisplaybasis import MaxDisplayBasis
from chromalab.visualizer import PSWrapper, DisplayBasisType, exportAndPlay, easeFunction
from chromalab.animation import Animation
# Out:
# objc[92201]: Class GLFWApplicationDelegate is implemented in both /Users/jessicalee/anaconda3/envs/chromalab/lib/python3.11/site-packages/open3d/cpu/pybind.cpython-311-darwin.so (0x2b5852e28) and /Users/jessicalee/anaconda3/envs/chromalab/lib/python3.11/site-packages/polyscope_bindings.cpython-311-darwin.so (0x2d42366f0). One of the two will be used. Which one is undefined.
# objc[92201]: Class GLFWWindowDelegate is implemented in both /Users/jessicalee/anaconda3/envs/chromalab/lib/python3.11/site-packages/open3d/cpu/pybind.cpython-311-darwin.so (0x2b5852db0) and /Users/jessicalee/anaconda3/envs/chromalab/lib/python3.11/site-packages/polyscope_bindings.cpython-311-darwin.so (0x2d4236718). One of the two will be used. Which one is undefined.
# objc[92201]: Class GLFWContentView is implemented in both /Users/jessicalee/anaconda3/envs/chromalab/lib/python3.11/site-packages/open3d/cpu/pybind.cpython-311-darwin.so (0x2b5852e50) and /Users/jessicalee/anaconda3/envs/chromalab/lib/python3.11/site-packages/polyscope_bindings.cpython-311-darwin.so (0x2d4236768). One of the two will be used. Which one is undefined.
# objc[92201]: Class GLFWWindow is implemented in both /Users/jessicalee/anaconda3/envs/chromalab/lib/python3.11/site-packages/open3d/cpu/pybind.cpython-311-darwin.so (0x2b5852ec8) and /Users/jessicalee/anaconda3/envs/chromalab/lib/python3.11/site-packages/polyscope_bindings.cpython-311-darwin.so (0x2d42367e0). One of the two will be used. Which one is undefined.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib ipympl

# %% [markdown]
# ## Create the Cone Fundamentals in 4D

# %%
wavelengths = np.arange(390, 830, 10)
d65 = Illuminant.get("D65")

# %%
tetrachromat = Observer.tetrachromat(wavelengths=wavelengths, illuminant=d65, verbose=True) 
# maxbasis = MaxBasis(tetrachromat, verbose=True)
# viz = PSWrapper(tetrachromat, maxbasis, itemsToDisplay=PSWrapper.ItemsToDisplay.BOTH, displayBasis=DisplayBasisType.MAXBASIS, verbose=True) 
 
trichromat = Observer.trichromat(wavelengths=wavelengths, illuminant=d65) 
# maxbasis_tri = MaxBasis(trichromat, verbose=True)
# # viz_tri = PSWrapper(trichromat, maxbasis_tri, itemsToDisplay=PSWrapper.ItemsToDisplay.MESH, displayBasis=DisplayBasisType.MAXBASIS, verbose=True)

# %%
mdb = MaxDisplayBasis(tetrachromat, True)
mdb.displayMaxPrimariesOnChromaticity()
# Out:
# Max Primaries -- (450.0, 530.0, 580.0, 620.0)
# Max Volume = 7.020710386921577e-05
# Volume Ratio Between n primaries / ideal = 0.5868654914193007
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mdb = MaxDisplayBasis(trichromat, True)
mdb.displayMaxPrimariesOnChromaticity()
# Out:
# Max Primaries -- (450, 530, 610)
# Max Volume = 0.009354588890913196
# Volume Ratio Between n primaries / ideal = 0.8593325816760645
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
