# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import numpy.typing as npt
import torch as th

# %%
from chromalab.observer import Observer, Cone
from chromalab.inks import Neugebauer, InkGamut, CellNeugebauer, Pigment
from chromalab.spectra import Spectra, Illuminant

# %%
from chromalab.inks import InkLibrary

# %%
# %load_ext autoreload
# %autoreload 2

# %%
wavelengths4 = np.arange(380, 781, 4)
wavelengths1 = np.arange(390, 701, 1)
wavelengths10 = np.arange(400, 701, 10)

# %%
tetrachromat_elevator = Observer.tetrachromat(illuminant=elevator_illuminant)

# %%
elevator_illuminant = Spectra(data=np.load("../data/illuminants/elevator.npy"), wavelengths=wavelengths4)

# %%
elevator_illuminant.plot()

# %%
mets = {}
with open(f'../data/nix/11.csv') as csvf:
    spamreader = csv.reader(csvf, delimiter=';')
    for i, row in enumerate(spamreader):
        if i < 4: continue
            
        name = row[4]
        color_data = np.array(row[33:],dtype=float)
        spectra = Spectra(data=color_data, wavelengths=wavelengths10)
    
        mets[name]  = spectra

# %%
premium_primaries = {}
with open(f'../data/nix/apr11.csv') as csvf:
    spamreader = csv.reader(csvf, delimiter=';')
    for i, row in enumerate(spamreader):
        if i < 4: continue
            
        name = row[4]
        color_data = np.array(row[33:],dtype=float)
        spectra = Spectra(data=color_data, wavelengths=wavelengths10)
    
        premium_primaries[name]  = spectra

# %%
premium_primaries
# Out:
# {'0000': <chromalab.spectra.Spectra at 0x2a9f9c4d0>,
#  '0001': <chromalab.spectra.Spectra at 0x2a9f9e590>,
#  '0010': <chromalab.spectra.Spectra at 0x2a9f9fdd0>,
#  '0011': <chromalab.spectra.Spectra at 0x2a9f90350>,
#  '0100': <chromalab.spectra.Spectra at 0x2a9f9de10>,
#  '0101': <chromalab.spectra.Spectra at 0x2a9f914d0>,
#  '0110': <chromalab.spectra.Spectra at 0x2a9f9e990>,
#  '0111': <chromalab.spectra.Spectra at 0x2a9f40550>,
#  '1000': <chromalab.spectra.Spectra at 0x2a9f9ec50>,
#  '1001': <chromalab.spectra.Spectra at 0x2a9f43cd0>,
#  '1010': <chromalab.spectra.Spectra at 0x2a9f9e8d0>,
#  '1011': <chromalab.spectra.Spectra at 0x2a9f87c10>,
#  '1100': <chromalab.spectra.Spectra at 0x2a9f9e550>,
#  '1101': <chromalab.spectra.Spectra at 0x2a9f85650>,
#  '1110': <chromalab.spectra.Spectra at 0x2a9f9d850>,
#  '1111': <chromalab.spectra.Spectra at 0x2a9f87510>}

# %%
premium_gamut = InkGamut(premium_primaries, illuminant=elevator_illuminant)

# %%
premium_gamut.get_width(tetrachromat_elevator, stepsize=0.05)
# Out:
# Generating point cloud: 2it [00:00,  5.41it/s]
# Point cloud generated.
# maximum distance is 0.018671834918664143 with percentages (0.10000000000000001, 0.10000000000000001, 0.35000000000000003, 0.60000000000000009) and (0.30000000000000004, 1.0, 0.050000000000000003, 0.0)
# 0.018671834918664143

# %% [markdown]
# (10, 10, 35, 60) and (30, 100, 5, 0)

# %%
tetrachromat_elevator.observe(premium_gamut.get_spectra((0.1, 0.1, 0.35, 0.6)))
# Out:
# array([ 0.21084082,  0.2764483 ,  0.31557276,  0.35621184])

# %%
tetrachromat_elevator.observe(premium_gamut.get_spectra((0.3, 1, 0.05, 0)))
# Out:
# array([ 0.20427506,  0.28917014,  0.33394688,  0.36398315])

# %%
mets
# Out:
# {'0000': <chromalab.spectra.Spectra at 0x2aaf82790>,
#  '0001': <chromalab.spectra.Spectra at 0x2ba0364d0>,
#  '0010': <chromalab.spectra.Spectra at 0x2ab203490>,
#  '0011': <chromalab.spectra.Spectra at 0x2b91554d0>,
#  '0100': <chromalab.spectra.Spectra at 0x2b917f8d0>,
#  '0101': <chromalab.spectra.Spectra at 0x2b9156750>,
#  '0110': <chromalab.spectra.Spectra at 0x2b917c810>,
#  '0111': <chromalab.spectra.Spectra at 0x2ab5370d0>,
#  '1000': <chromalab.spectra.Spectra at 0x34dc59b90>,
#  '1001': <chromalab.spectra.Spectra at 0x2b9156a50>,
#  '1010': <chromalab.spectra.Spectra at 0x2aaf4f950>,
#  '1011': <chromalab.spectra.Spectra at 0x34dd2ac50>,
#  '1100': <chromalab.spectra.Spectra at 0x34dae3f10>,
#  '1101': <chromalab.spectra.Spectra at 0x2b9263610>,
#  '1110': <chromalab.spectra.Spectra at 0x34dae0890>,
#  '1111': <chromalab.spectra.Spectra at 0x2ab604310>,
#  'Outside': <chromalab.spectra.Spectra at 0x34dae3c90>,
#  'Inside': <chromalab.spectra.Spectra at 0x2ab84c910>,
#  '50,0,0,0': <chromalab.spectra.Spectra at 0x34de12050>,
#  '0,50,0,0': <chromalab.spectra.Spectra at 0x2ab03c3d0>,
#  '0,0,50,0': <chromalab.spectra.Spectra at 0x34de11910>,
#  '0,0,0,50': <chromalab.spectra.Spectra at 0x2ab4d0cd0>}

# %%
premium_gamut.get_spectra((0, 0, 0.5, 0)).plot()
mets["0,0,50,0"].plot(color='black')

# %%
premium_gamut.get_spectra((0, 0, 0.5, 0)).plot()
# premium_gamut.get_spectra((0.5,0,0,0)).plot()
premium_gamut.get_spectra((0,0.5,0,0)).plot()
premium_gamut.get_spectra((0,0,0,0.5)).plot()

# %%
premium_gamut.get_spectra((0.1, 0.1, 0.35, 0.6)).plot()

mets["Outside"].plot(color='black')

# %%
premium_gamut.get_spectra((0.02, 0.05, 0.15, 0.6)).plot()
mets["Outside"].plot(color='black')

# %%
premium_gamut.get_spectra((0.3, 1, 0.05, 0)).plot()
mets["Inside"].plot()
